# %%
# coding=utf-8
import sys
import importlib
import uniout
import json
import 


from pdfminer.pdfparser import PDFParser
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator
from pdfminer.layout import LTTextBoxHorizontal,LAParams
from pdfminer.pdfdocument import PDFTextExtractionNotAllowed


def parse(path):
    fp = open(path, 'rb') # 以二进制读模式打开
    #用文件对象来创建一个pdf文档分析器
    praser = PDFParser(fp)
    # 创建一个PDF文档
    doc = PDFDocument(praser)
    # 连接分析器 与文档对象
    praser.set_document(doc)
    #doc.set_parser(praser)

    outlines = doc.get_outlines()
    for (level,title,dest,a,se) in outlines:
        print level, json.dumps(title, ensure_ascii=False)

if __name__ == '__main__':
    path =r'C:/Users/raymond-r.zhang/Desktop/Python Scripts/capital_commitment/000895.pdf'
    parse(path)
# Out:
# 1 "第一节 重要提示、目录和释义"
# 1 "第二节 公司简介和主要财务指标"
# 2 "一、公司信息"
# 2 "二、联系人和联系方式"
# 2 "三、信息披露及备置地点"
# 2 "四、注册变更情况"
# 2 "五、其他有关资料"
# 2 "六、主要会计数据和财务指标"
# 2 "七、境内外会计准则下会计数据差异"
# 3 "1、同时按照国际会计准则与按照中国会计准则披露的财务报告中净利润和净资产差异情况"
# 3 "2、同时按照境外会计准则与按照中国会计准则披露的财务报告中净利润和净资产差异情况"
# 2 "八、分季度主要财务指标"
# 2 "九、非经常性损益项目及金额"
# 1 "第三节 公司业务概要"
# 2 "一、报告期内公司从事的主要业务"
# 2 "二、主要资产重大变化情况"
# 3 "1、主要资产重大变化情况"
# 3 "2、主要境外资产情况"
# 2 "三、核心竞争力分析"
# 1 "第四节 经营情况讨论与分析"
# 2 "一、概述"
# 2 "二、主营业务分析"
# 3 "1、概述"
# 3 "2、收入与成本"
# 4 "（1）营业收入构成"
# 4 "（2）占公司营业收入或营业利润10%以上的行业、产品或地区情况"
# 4 "（3）公司实物销售收入是否大于劳务收入"
# 4 "（4）公司已签订的重大销售合同截至本报告期的履行情况"
# 4 "（5）营业成本构成"
# 4 "（6）报告期内合并范围是否发生变动"
# 4 "（7）公司报告期内业务、产品或服务发生重大变化或调整有关情况"
# 4 "（8）主要销售客户和主要供应商情况"
# 3 "3、费用"
# 3 "4、研发投入"
# 3 "5、现金流"
# 2 "三、非主营业务分析"
# 2 "四、资产及负债状况"
# 3 "1、资产构成重大变动情况"
# 3 "2、以公允价值计量的资产和负债"
# 3 "3、截至报告期末的资产权利受限情况"
# 2 "五、投资状况"
# 3 "1、总体情况"
# 3 "2、报告期内获取的重大的股权投资情况"
# 3 "3、报告期内正在进行的重大的非股权投资情况"
# 3 "4、金融资产投资"
# 4 "（1）证券投资情况"
# 4 "（2）衍生品投资情况"
# 3 "5、募集资金使用情况"
# 2 "六、重大资产和股权出售"
# 3 "1、出售重大资产情况"
# 3 "2、出售重大股权情况"
# 2 "七、主要控股参股公司分析"
# 2 "八、公司控制的结构化主体情况"
# 2 "九、公司未来发展的展望"
# 2 "十、接待调研、沟通、采访等活动情况"
# 3 "1、报告期内接待调研、沟通、采访等活动登记表"
# 1 "第五节 重要事项"
# 2 "一、公司普通股利润分配及资本公积金转增股本情况"
# 2 "二、本报告期利润分配及资本公积金转增股本预案"
# 2 "三、承诺事项履行情况"
# 3 "1、公司实际控制人、股东、关联方、收购人以及公司等承诺相关方在报告期内履行完毕及截至报告期末尚未履行完毕的承诺事项"
# 3 "2、公司资产或项目存在盈利预测，且报告期仍处在盈利预测期间，公司就资产或项目达到原盈利预测及其原因做出说明"
# 2 "四、控股股东及其关联方对上市公司的非经营性占用资金情况"
# 2 "五、董事会、监事会、独立董事（如有）对会计师事务所本报告期“非标准审计报告”的说明"
# 2 "六、与上年度财务报告相比，会计政策、会计估计和核算方法发生变化的情况说明"
# 2 "七、报告期内发生重大会计差错更正需追溯重述的情况说明"
# 2 "八、与上年度财务报告相比，合并报表范围发生变化的情况说明"
# 2 "九、聘任、解聘会计师事务所情况"
# 2 "十、年度报告披露后面临暂停上市和终止上市情况"
# 2 "十一、破产重整相关事项"
# 2 "十二、重大诉讼、仲裁事项"
# 2 "十三、处罚及整改情况"
# 2 "十四、公司及其控股股东、实际控制人的诚信状况"
# 2 "十五、公司股权激励计划、员工持股计划或其他员工激励措施的实施情况"
# 2 "十六、重大关联交易"
# 3 "1、与日常经营相关的关联交易"
# 3 "2、资产或股权收购、出售发生的关联交易"
# 3 "3、共同对外投资的关联交易"
# 3 "4、关联债权债务往来"
# 3 "5、其他重大关联交易"
# 2 "十七、重大合同及其履行情况"
# 3 "1、托管、承包、租赁事项情况"
# 4 "（1）托管情况"
# 4 "（2）承包情况"
# 4 "（3）租赁情况"
# 3 "2、重大担保"
# 3 "3、委托他人进行现金资产管理情况"
# 4 "（1）委托理财情况"
# 4 "（2）委托贷款情况"
# 3 "4、其他重大合同"
# 2 "十八、社会责任情况"
# 3 "1、履行社会责任情况"
# 3 "2、履行精准扶贫社会责任情况"
# 4 "（1）精准扶贫规划"
# 4 "（2）年度精准扶贫概要"
# 4 "（3）精准扶贫成效"
# 4 "（4）后续精准扶贫计划"
# 3 "3、环境保护相关的情况"
# 2 "十九、其他重大事项的说明"
# 2 "二十、公司子公司重大事项"
# 1 "第六节 股份变动及股东情况"
# 2 "一、股份变动情况"
# 3 "1、股份变动情况"
# 3 "2、限售股份变动情况"
# 2 "二、证券发行与上市情况"
# 3 "1、报告期内证券发行（不含优先股）情况"
# 3 "2、公司股份总数及股东结构的变动、公司资产和负债结构的变动情况说明"
# 3 "3、现存的内部职工股情况"
# 2 "三、股东和实际控制人情况"
# 3 "1、公司股东数量及持股情况"
# 3 "2、公司控股股东情况"
# 3 "3、公司实际控制人情况"
# 3 "4、其他持股在10%以上的法人股东"
# 3 "5、控股股东、实际控制人、重组方及其他承诺主体股份限制减持情况"
# 1 "第七节 优先股相关情况"
# 1 "第八节 董事、监事、高级管理人员和员工情况"
# 2 "一、董事、监事和高级管理人员持股变动"
# 2 "二、公司董事、监事、高级管理人员变动情况"
# 2 "三、任职情况"
# 2 "四、董事、监事、高级管理人员报酬情况"
# 2 "五、公司员工情况"
# 3 "1、员工数量、专业构成及教育程度"
# 3 "2、薪酬政策"
# 3 "3、培训计划"
# 3 "4、劳务外包情况"
# 1 "第九节 公司治理"
# 2 "一、公司治理的基本状况"
# 2 "二、公司相对于控股股东在业务、人员、资产、机构、财务等方面的独立情况"
# 2 "三、同业竞争情况"
# 2 "四、报告期内召开的年度股东大会和临时股东大会的有关情况"
# 3 "1、本报告期股东大会情况"
# 3 "2、表决权恢复的优先股股东请求召开临时股东大会"
# 2 "五、报告期内独立董事履行职责的情况"
# 3 "1、独立董事出席董事会及股东大会的情况"
# 3 "2、独立董事对公司有关事项提出异议的情况"
# 3 "3、独立董事履行职责的其他说明"
# 2 "六、董事会下设专门委员会在报告期内履行职责情况"
# 2 "七、监事会工作情况"
# 2 "八、高级管理人员的考评及激励情况"
# 2 "九、内部控制情况"
# 3 "1、报告期内发现的内部控制重大缺陷的具体情况"
# 3 "2、内控自我评价报告"
# 2 "十、内部控制审计报告"
# 1 "第十节 公司债券相关情况"
# 1 "第十一节 财务报告"
# 2 "一、审计报告"
# 2 "二、财务报表"
# 3 "1、合并资产负债表"
# 3 "2、母公司资产负债表"
# 3 "3、合并利润表"
# 3 "4、母公司利润表"
# 3 "5、合并现金流量表"
# 3 "6、母公司现金流量表"
# 3 "7、合并所有者权益变动表"
# 3 "8、母公司所有者权益变动表"
# 2 "三、公司基本情况"
# 2 "四、财务报表的编制基础"
# 3 "1、编制基础"
# 3 "2、持续经营"
# 2 "五、重要会计政策及会计估计"
# 3 "1、遵循企业会计准则的声明"
# 3 "2、会计期间"
# 3 "3、营业周期"
# 3 "4、记账本位币"
# 3 "5、同一控制下和非同一控制下企业合并的会计处理方法"
# 3 "6、合并财务报表的编制方法"
# 3 "7、合营安排分类及共同经营会计处理方法"
# 3 "8、现金及现金等价物的确定标准"
# 3 "9、外币业务和外币报表折算"
# 3 "10、金融工具"
# 3 "11、应收款项"
# 4 "（1）单项金额重大并单独计提坏账准备的应收款项"
# 4 "（2）按信用风险特征组合计提坏账准备的应收款项"
# 4 "（3）单项金额不重大但单独计提坏账准备的应收款项"
# 3 "12、存货"
# 3 "13、 发放贷款及垫款"
# 3 "14、持有待售资产"
# 3 "15、长期股权投资"
# 3 "16、投资性房地产"
# 3 "17、固定资产"
# 4 "（1）确认条件"
# 4 "（2）折旧方法"
# 4 "（3）融资租入固定资产的认定依据、计价和折旧方法"
# 3 "18、在建工程"
# 3 "19、借款费用"
# 3 "20、生物资产"
# 3 "21、油气资产"
# 3 "22、无形资产"
# 4 "（1）计价方法、使用寿命、减值测试"
# 4 "（2）内部研究开发支出会计政策"
# 3 "23、长期资产减值"
# 3 "24、长期待摊费用"
# 3 "25、职工薪酬"
# 4 "（1）短期薪酬的会计处理方法"
# 4 "（2）离职后福利的会计处理方法"
# 4 "（3）辞退福利的会计处理方法"
# 4 "（4）其他长期职工福利的会计处理方法"
# 3 "26、预计负债"
# 3 "27、股份支付"
# 3 "28、优先股、永续债等其他金融工具"
# 3 "29、收入"
# 3 "30、政府补助"
# 4 "（1）与资产相关的政府补助判断依据及会计处理方法"
# 4 "（2）与收益相关的政府补助判断依据及会计处理方法"
# 3 "31、递延所得税资产/递延所得税负债"
# 3 "32、租赁"
# 4 "（1）经营租赁的会计处理方法"
# 4 "（2）融资租赁的会计处理方法"
# 3 "33、其他重要的会计政策和会计估计"
# 3 "34、重要会计政策和会计估计变更"
# 4 "（1）重要会计政策变更"
# 4 "（2）重要会计估计变更"
# 3 "35、其他"
# 2 "六、税项"
# 3 "1、主要税种及税率"
# 3 "2、税收优惠"
# 3 "3、其他"
# 2 "七、合并财务报表项目注释"
# 3 "1、货币资金"
# 3 "2、以公允价值计量且其变动计入当期损益的金融资产"
# 3 "3、衍生金融资产"
# 3 "4、应收票据"
# 4 "（1）应收票据分类列示"
# 4 "（2）期末公司已质押的应收票据"
# 4 "（3）期末公司已背书或贴现且在资产负债表日尚未到期的应收票据"
# 4 "（4）期末公司因出票人未履约而将其转应收账款的票据"
# 3 "5、应收账款"
# 4 "（1）应收账款分类披露"
# 4 "（2）本期计提、收回或转回的坏账准备情况"
# 4 "（3）本期实际核销的应收账款情况"
# 4 "（4）按欠款方归集的期末余额前五名的应收账款情况"
# 4 "（5）因金融资产转移而终止确认的应收账款"
# 4 "（6）转移应收账款且继续涉入形成的资产、负债金额"
# 3 "6、预付款项"
# 4 "（1）预付款项按账龄列示"
# 4 "（2）按预付对象归集的期末余额前五名的预付款情况"
# 3 "7、应收利息"
# 4 "（1）应收利息分类"
# 4 "（2）重要逾期利息"
# 3 "8、应收股利"
# 4 "（1）应收股利"
# 4 "（2）重要的账龄超过1年的应收股利"
# 3 "9、其他应收款"
# 4 "（1）其他应收款分类披露"
# 4 "（2）本期计提、收回或转回的坏账准备情况"
# 4 "（3）本期实际核销的其他应收款情况"
# 4 "（4）其他应收款按款项性质分类情况"
# 4 "（5）按欠款方归集的期末余额前五名的其他应收款情况"
# 4 "（6）涉及政府补助的应收款项"
# 4 "（7）因金融资产转移而终止确认的其他应收款"
# 4 "（8）转移其他应收款且继续涉入形成的资产、负债金额"
# 3 "10、存货"
# 4 "（1）存货分类"
# 4 "（2）存货跌价准备"
# 4 "（3）存货期末余额含有借款费用资本化金额的说明"
# 4 "（4）期末建造合同形成的已完工未结算资产情况"
# 3 "11、持有待售的资产"
# 3 "12、一年内到期的非流动资产"
# 3 "13、 发放贷款及垫款"
# 3 "14、其他流动资产"
# 3 "15、可供出售金融资产"
# 4 "（1）可供出售金融资产情况"
# 4 "（2）期末按公允价值计量的可供出售金融资产"
# 4 "（3）期末按成本计量的可供出售金融资产"
# 4 "（4）报告期内可供出售金融资产减值的变动情况"
# 4 "（5）可供出售权益工具期末公允价值严重下跌或非暂时性下跌但未计提减值准备的相关说明"
# 3 "16、持有至到期投资"
# 4 "（1）持有至到期投资情况"
# 4 "（2）期末重要的持有至到期投资"
# 4 "（3）本期重分类的持有至到期投资"
# 3 "17、长期应收款"
# 4 "（1）长期应收款情况"
# 4 "（2）因金融资产转移而终止确认的长期应收款"
# 4 "（3）转移长期应收款且继续涉入形成的资产、负债金额"
# 3 "18、长期股权投资"
# 3 "19、投资性房地产"
# 4 "（1）采用成本计量模式的投资性房地产"
# 4 "（2）采用公允价值计量模式的投资性房地产"
# 4 "（3）未办妥产权证书的投资性房地产情况"
# 3 "20、固定资产"
# 4 "（1）固定资产情况"
# 4 "（2）暂时闲置的固定资产情况"
# 4 "（3）通过融资租赁租入的固定资产情况"
# 4 "（4）通过经营租赁租出的固定资产"
# 4 "（5）未办妥产权证书的固定资产情况"
# 3 "21、在建工程"
# 4 "（1）在建工程情况"
# 4 "（2）重要在建工程项目本期变动情况"
# 4 "（3）本期计提在建工程减值准备情况"
# 3 "22、工程物资"
# 3 "23、固定资产清理"
# 3 "24、生产性生物资产"
# 4 "（1）采用成本计量模式的生产性生物资产"
# 4 "（2）采用公允价值计量模式的生产性生物资产"
# 3 "25、油气资产"
# 3 "26、无形资产"
# 4 "（1）无形资产情况"
# 4 "（2）未办妥产权证书的土地使用权情况"
# 3 "27、开发支出"
# 3 "28、商誉"
# 4 "（1）商誉账面原值"
# 4 "（2）商誉减值准备"
# 3 "29、长期待摊费用"
# 3 "30、递延所得税资产/递延所得税负债"
# 4 "（1）未经抵销的递延所得税资产"
# 4 "（2）未经抵销的递延所得税负债"
# 4 "（3）以抵销后净额列示的递延所得税资产或负债"
# 4 "（4）未确认递延所得税资产明细"
# 4 "（5）未确认递延所得税资产的可抵扣亏损将于以下年度到期"
# 3 "31、其他非流动资产"
# 3 "32、短期借款"
# 4 "（1）短期借款分类"
# 4 "（2）已逾期未偿还的短期借款情况"
# 3 "33、 吸收存款及同业存放"
# 3 "34、以公允价值计量且其变动计入当期损益的金融负债"
# 3 "35、衍生金融负债"
# 3 "36、 卖出回购金融资产款"
# 3 "37、应付票据"
# 3 "38、应付账款"
# 4 "（1）应付账款列示"
# 4 "（2）账龄超过1年的重要应付账款"
# 3 "39、预收款项"
# 4 "（1）预收款项列示"
# 4 "（2）账龄超过1年的重要预收款项"
# 4 "（3）期末建造合同形成的已结算未完工项目情况"
# 3 "40、应付职工薪酬"
# 4 "（1）应付职工薪酬列示"
# 4 "（2）短期薪酬列示"
# 4 "（3）设定提存计划列示"
# 3 "41、应交税费"
# 3 "42、应付利息"
# 3 "43、应付股利"
# 3 "44、其他应付款"
# 4 "（1）按款项性质列示其他应付款"
# 4 "（2）账龄超过1年的重要其他应付款"
# 3 "45、持有待售的负债"
# 3 "46、一年内到期的非流动负债"
# 3 "47、其他流动负债"
# 3 "48、长期借款"
# 4 "（1）长期借款分类"
# 3 "49、应付债券"
# 4 "（1）应付债券"
# 4 "（2）应付债券的增减变动（不包括划分为金融负债的优先股、永续债等其他金融工具）"
# 4 "（3）可转换公司债券的转股条件、转股时间说明"
# 4 "（4）划分为金融负债的其他金融工具说明"
# 3 "50、长期应付款"
# 4 "（1）按款项性质列示长期应付款"
# 3 "51、长期应付职工薪酬"
# 4 "（1）长期应付职工薪酬表"
# 4 "（2）设定受益计划变动情况"
# 3 "52、专项应付款"
# 3 "53、预计负债"
# 3 "54、递延收益"
# 3 "55、其他非流动负债"
# 3 "56、股本"
# 3 "57、其他权益工具"
# 4 "（1）期末发行在外的优先股、永续债等其他金融工具基本情况"
# 4 "（2）期末发行在外的优先股、永续债等金融工具变动情况表"
# 3 "58、资本公积"
# 3 "59、库存股"
# 3 "60、其他综合收益"
# 3 "61、专项储备"
# 3 "62、盈余公积"
# 3 "63、 一般风险准备"
# 3 "64、未分配利润"
# 3 "65、营业收入和营业成本"
# 3 "66、税金及附加"
# 3 "67、销售费用"
# 3 "68、管理费用"
# 3 "69、财务费用"
# 3 "70、资产减值损失"
# 3 "71、公允价值变动收益"
# 3 "72、投资收益"
# 3 "73、资产处置收益"
# 3 "74、其他收益"
# 3 "75、营业外收入"
# 3 "76、营业外支出"
# 3 "77、所得税费用"
# 4 "（1）所得税费用表"
# 4 "（2）会计利润与所得税费用调整过程"
# 3 "78、其他综合收益"
# 3 "79、现金流量表项目"
# 4 "（1）收到的其他与经营活动有关的现金"
# 4 "（2）支付的其他与经营活动有关的现金"
# 4 "（3）收到的其他与投资活动有关的现金"
# 4 "（4）支付的其他与投资活动有关的现金"
# 4 "（5）收到的其他与筹资活动有关的现金"
# 4 "（6）支付的其他与筹资活动有关的现金"
# 3 "80、现金流量表补充资料"
# 4 "（1）现金流量表补充资料"
# 4 "（2）本期支付的取得子公司的现金净额"
# 4 "（3）本期收到的处置子公司的现金净额"
# 4 "（4）现金和现金等价物的构成"
# 3 "81、所有者权益变动表项目注释"
# 3 "82、所有权或使用权受到限制的资产"
# 3 "83、外币货币性项目"
# 4 "（1）外币货币性项目"
# 4 "（2）境外经营实体说明，包括对于重要的境外经营实体，应披露其境外主要经营地、记账本位币及选择依据，记账本位币发生变化的还应披露原因。"
# 3 "84、套期"
# 3 "85、其他"
# 2 "八、合并范围的变更"
# 3 "1、非同一控制下企业合并"
# 4 "（1）本期发生的非同一控制下企业合并"
# 4 "（2）合并成本及商誉"
# 4 "（3）被购买方于购买日可辨认资产、负债"
# 4 "（4）购买日之前持有的股权按照公允价值重新计量产生的利得或损失"
# 4 "（5）购买日或合并当期期末无法合理确定合并对价或被购买方可辨认资产、负债公允价值的相关说明"
# 4 "（6）其他说明"
# 3 "2、同一控制下企业合并"
# 4 "（1）本期发生的同一控制下企业合并"
# 4 "（2）合并成本"
# 4 "（3）合并日被合并方资产、负债的账面价值"
# 3 "3、反向购买"
# 3 "4、处置子公司"
# 3 "5、其他原因的合并范围变动"
# 3 "6、其他"
# 2 "九、在其他主体中的权益"
# 3 "1、在子公司中的权益"
# 4 "（1）企业集团的构成"
# 4 "（2）重要的非全资子公司"
# 4 "（3）重要非全资子公司的主要财务信息"
# 4 "（4）使用企业集团资产和清偿企业集团债务的重大限制"
# 4 "（5）向纳入合并财务报表范围的结构化主体提供的财务支持或其他支持"
# 3 "2、在子公司的所有者权益份额发生变化且仍控制子公司的交易"
# 4 "（1）在子公司所有者权益份额发生变化的情况说明"
# 4 "（2）交易对于少数股东权益及归属于母公司所有者权益的影响"
# 3 "3、在合营安排或联营企业中的权益"
# 4 "（1）重要的合营企业或联营企业"
# 4 "（2）重要合营企业的主要财务信息"
# 4 "（3）重要联营企业的主要财务信息"
# 4 "（4）不重要的合营企业和联营企业的汇总财务信息"
# 4 "（5）合营企业或联营企业向本公司转移资金的能力存在重大限制的说明"
# 4 "（6）合营企业或联营企业发生的超额亏损"
# 4 "（7）与合营企业投资相关的未确认承诺"
# 4 "（8）与合营企业或联营企业投资相关的或有负债"
# 3 "4、重要的共同经营"
# 3 "5、在未纳入合并财务报表范围的结构化主体中的权益"
# 3 "6、其他"
# 2 "十、与金融工具相关的风险"
# 2 "十一、公允价值的披露"
# 3 "1、以公允价值计量的资产和负债的期末公允价值"
# 3 "2、持续和非持续第一层次公允价值计量项目市价的确定依据"
# 3 "3、持续和非持续第二层次公允价值计量项目，采用的估值技术和重要参数的定性及定量信息"
# 3 "4、持续和非持续第三层次公允价值计量项目，采用的估值技术和重要参数的定性及定量信息"
# 3 "5、持续的第三层次公允价值计量项目，期初与期末账面价值间的调节信息及不可观察参数敏感性分析"
# 3 "6、持续的公允价值计量项目，本期内发生各层级之间转换的，转换的原因及确定转换时点的政策"
# 3 "7、本期内发生的估值技术变更及变更原因"
# 3 "8、不以公允价值计量的金融资产和金融负债的公允价值情况"
# 3 "9、其他"
# 2 "十二、关联方及关联交易"
# 3 "1、本企业的母公司情况"
# 3 "2、本企业的子公司情况"
# 3 "3、本企业合营和联营企业情况"
# 3 "4、其他关联方情况"
# 3 "5、关联交易情况"
# 4 "（1）购销商品、提供和接受劳务的关联交易"
# 4 "（2）关联受托管理/承包及委托管理/出包情况"
# 4 "（3）关联租赁情况"
# 4 "（4）关联担保情况"
# 4 "（5）关联方资金拆借"
# 4 "（6）关联方资产转让、债务重组情况"
# 4 "（7）关键管理人员报酬"
# 4 "（8）其他关联交易"
# 3 "6、关联方应收应付款项"
# 4 "（1）应收项目"
# 4 "（2）应付项目"
# 3 "7、关联方承诺"
# 3 "8、其他"
# 2 "十三、股份支付"
# 3 "1、股份支付总体情况"
# 3 "2、以权益结算的股份支付情况"
# 3 "3、以现金结算的股份支付情况"
# 3 "4、股份支付的修改、终止情况"
# 3 "5、其他"
# 2 "十四、承诺及或有事项"
# 3 "1、重要承诺事项"
# 3 "2、或有事项"
# 4 "（1）资产负债表日存在的重要或有事项"
# 4 "（2）公司没有需要披露的重要或有事项，也应予以说明"
# 3 "3、其他"
# 2 "十五、资产负债表日后事项"
# 3 "1、重要的非调整事项"
# 3 "2、利润分配情况"
# 3 "3、销售退回"
# 3 "4、其他资产负债表日后事项说明"
# 2 "十六、其他重要事项"
# 3 "1、前期会计差错更正"
# 4 "（1）追溯重述法"
# 4 "（2）未来适用法"
# 3 "2、债务重组"
# 3 "3、资产置换"
# 4 "（1）非货币性资产交换"
# 4 "（2）其他资产置换"
# 3 "4、年金计划"
# 3 "5、终止经营"
# 3 "6、分部信息"
# 4 "（1）报告分部的确定依据与会计政策"
# 4 "（2）报告分部的财务信息"
# 4 "（3）公司无报告分部的，或者不能披露各报告分部的资产总额和负债总额的，应说明原因"
# 4 "（4）其他说明"
# 3 "7、其他对投资者决策有影响的重要交易和事项"
# 3 "8、其他"
# 2 "十七、母公司财务报表主要项目注释"
# 3 "1、应收账款"
# 4 "（1）应收账款分类披露"
# 4 "（2）本期计提、收回或转回的坏账准备情况"
# 4 "（3）本期实际核销的应收账款情况"
# 4 "（4）按欠款方归集的期末余额前五名的应收账款情况"
# 4 "（5）因金融资产转移而终止确认的应收账款"
# 4 "（6）转移应收账款且继续涉入形成的资产、负债金额"
# 3 "2、其他应收款"
# 4 "（1）其他应收款分类披露"
# 4 "（2）本期计提、收回或转回的坏账准备情况"
# 4 "（3）本期实际核销的其他应收款情况"
# 4 "（4）其他应收款按款项性质分类情况"
# 4 "（5）按欠款方归集的期末余额前五名的其他应收款情况"
# 4 "（6）涉及政府补助的应收款项"
# 4 "（7）因金融资产转移而终止确认的其他应收款"
# 4 "（8）转移其他应收款且继续涉入形成的资产、负债金额"
# 3 "3、长期股权投资"
# 4 "（1）对子公司投资"
# 4 "（2）对联营、合营企业投资"
# 4 "（3）其他说明"
# 3 "4、营业收入和营业成本"
# 3 "5、投资收益"
# 3 "6、其他"
# 2 "十八、补充资料"
# 3 "1、当期非经常性损益明细表"
# 3 "2、净资产收益率及每股收益"
# 3 "3、境内外会计准则下会计数据差异"
# 4 "（1）同时按照国际会计准则与按中国会计准则披露的财务报告中净利润和净资产差异情况"
# 4 "（2）同时按照境外会计准则与按中国会计准则披露的财务报告中净利润和净资产差异情况"
# 4 "（3）境内外会计准则下会计数据差异原因说明，对已经境外审计机构审计的数据进行差异调节的，应注明该境外机构的名称"
# 3 "4、其他"
# 1 "第十二节 备查文件目录"
